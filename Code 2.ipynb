# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import os
import pandas as pd
import ccxt

# %%
# Import environment variables
kraken_public_key = os.getenv('KRAKEN_PUBLIC_KEY')
kraken_secret_key = os.getenv('KRAKEN_SECRET_KEY')
COIN_MARKET_KEY = os.getenv('COIN_MARKET_KEY')

# Set the public and private keys for the KRAKEN API
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
})

# %%
# Connect to CoinMarketCap and load the available cryptocurrencies
url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': COIN_MARKET_KEY,
}
session = Session()
session.headers.update(headers)
try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
#   print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame.from_dict(data['data'])

# %%
crypto_df[['USD']] = pd.DataFrame(crypto_df.quote.values.tolist())
crypto_df[['Price', 'Volume_24h', 'Percent_change_1h', 'Percent_change_24h', 'Percent_change_7d', 'Market_cap', 'Last_updated']] = pd.DataFrame(crypto_df.USD.values.tolist())

# %%
crypto_df.drop(crypto_df.columns.difference(['cmc_rank', 'name', 'symbol', 'tags', 'Price', 'circulating_supply', 'total_supply', 'Volume_24h', 'Market_cap', 'max_supply']), 1, inplace=False)
crypto_df = crypto_df[['cmc_rank', 'name', 'symbol', 'tags', 'Price', 'circulating_supply', 'total_supply', 'max_supply', 'Volume_24h', 'Market_cap']]

# %%
crypto_df_20 = crypto_df.sort_values(by='Volume_24h', ascending=False)
crypto_df_20.head()
# Out:
#    cmc_rank          name symbol        tags                     Price  \
# 0         1       Bitcoin    BTC  [mineable]  2019-08-30T18:51:28.000Z
# 1         2      Ethereum    ETH  [mineable]  2019-08-30T18:51:21.000Z
# 2         3           XRP    XRP          []  2019-08-30T18:51:03.000Z
# 3         4  Bitcoin Cash    BCH  [mineable]  2019-08-30T18:51:08.000Z
# 4         5      Litecoin    LTC  [mineable]  2019-08-30T18:51:04.000Z
#
#    circulating_supply  total_supply    max_supply    Volume_24h   Market_cap
# 0        1.790601e+07  1.790601e+07  2.100000e+07  1.711555e+11  9558.551637
# 1        1.075379e+08  1.075379e+08           NaN  1.814043e+10   168.688634
# 2        4.293287e+10  9.999137e+10  1.000000e+11  1.092420e+10     0.254449
# 3        1.797598e+07  1.797598e+07  2.100000e+07  5.051770e+09   281.029003
# 4        6.314712e+07  6.314712e+07  8.400000e+07  4.063460e+09    64.349090

# %%
# Connect to Kraken and load the available cryptocurrencies
crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
crypto_details_1 = pd.DataFrame(crypto_details)
crypto_details_1
# Out:
#                                                       ADA/ETH  \
# active                                                   True
# altname                                                ADAETH
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAETH
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 7}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                                ADA/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/EUR  \
# active                                                   True
# altname                                                ADAEUR
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAEUR
# info        {'altname': 'ADAEUR', 'wsname': 'ADA/EUR', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                ADA/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/USD  \
# active                                                   True
# altname                                                ADAUSD
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAUSD
# info        {'altname': 'ADAUSD', 'wsname': 'ADA/USD', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                ADA/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/BTC  \
# active                                                   True
# altname                                                ADAXBT
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAXBT
# info        {'altname': 'ADAXBT', 'wsname': 'ADA/XBT', 'ac...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 8}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                                ADA/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/ETH  \
# active                                                   True
# altname                                               ALGOETH
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOETH
# info        {'altname': 'ALGOETH', 'wsname': 'ALGO/ETH', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 7}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                               ALGO/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/EUR  \
# active                                                   True
# altname                                               ALGOEUR
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOEUR
# info        {'altname': 'ALGOEUR', 'wsname': 'ALGO/EUR', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                               ALGO/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/USD  \
# active                                                   True
# altname                                               ALGOUSD
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOUSD
# info        {'altname': 'ALGOUSD', 'wsname': 'ALGO/USD', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                               ALGO/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/BTC  \
# active                                                   True
# altname                                               ALGOXBT
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOXBT
# info        {'altname': 'ALGOXBT', 'wsname': 'ALGO/XBT', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 8}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                               ALGO/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ATOM/ETH  \
# active                                                   True
# altname                                               ATOMETH
# base                                                     ATOM
# baseId                                                   ATOM
# darkpool                                                False
# id                                                    ATOMETH
# info        {'altname': 'ATOMETH', 'wsname': 'ATOM/ETH', '...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                               ATOM/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ATOM/EUR  ...  \
# active                                                   True  ...
# altname                                               ATOMEUR  ...
# base                                                     ATOM  ...
# baseId                                                   ATOM  ...
# darkpool                                                False  ...
# id                                                    ATOMEUR  ...
# info        {'altname': 'ATOMEUR', 'wsname': 'ATOM/EUR', '...  ...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...  ...
# maker                                                  0.0016  ...
# percentage                                               True  ...
# precision                           {'amount': 8, 'price': 4}  ...
# quote                                                     EUR  ...
# quoteId                                                  ZEUR  ...
# symbol                                               ATOM/EUR  ...
# taker                                                  0.0026  ...
# tierBased                                                True  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
#
#                                                       XRP/EUR  \
# active                                                   True
# altname                                                XRPEUR
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZEUR
# info        {'altname': 'XRPEUR', 'wsname': 'XRP/EUR', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                XRP/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       XRP/JPY  \
# active                                                   True
# altname                                                XRPJPY
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZJPY
# info        {'altname': 'XRPJPY', 'wsname': 'XRP/JPY', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     JPY
# quoteId                                                  ZJPY
# symbol                                                XRP/JPY
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       XRP/USD  \
# active                                                   True
# altname                                                XRPUSD
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZUSD
# info        {'altname': 'XRPUSD', 'wsname': 'XRP/USD', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                XRP/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/BTC  \
# active                                                   True
# altname                                                ZECXBT
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECXXBT
# info        {'altname': 'ZECXBT', 'wsname': 'ZEC/XBT', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                                ZEC/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/EUR  \
# active                                                   True
# altname                                                ZECEUR
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECZEUR
# info        {'altname': 'ZECEUR', 'wsname': 'ZEC/EUR', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                ZEC/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/USD  \
# active                                                   True
# altname                                                ZECUSD
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECZUSD
# info        {'altname': 'ZECUSD', 'wsname': 'ZEC/USD', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 2}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                ZEC/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       EUR/USD  \
# active                                                   True
# altname                                                EURUSD
# base                                                      EUR
# baseId                                                   ZEUR
# darkpool                                                False
# id                                                   ZEURZUSD
# info        {'altname': 'EURUSD', 'wsname': 'EUR/USD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                EUR/USD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       GBP/USD  \
# active                                                   True
# altname                                                GBPUSD
# base                                                      GBP
# baseId                                                   ZGBP
# darkpool                                                False
# id                                                   ZGBPZUSD
# info        {'altname': 'GBPUSD', 'wsname': 'GBP/USD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                GBP/USD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       USD/CAD  \
# active                                                   True
# altname                                                USDCAD
# base                                                      USD
# baseId                                                   ZUSD
# darkpool                                                False
# id                                                   ZUSDZCAD
# info        {'altname': 'USDCAD', 'wsname': 'USD/CAD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     CAD
# quoteId                                                  ZCAD
# symbol                                                USD/CAD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       USD/JPY
# active                                                   True
# altname                                                USDJPY
# base                                                      USD
# baseId                                                   ZUSD
# darkpool                                                False
# id                                                   ZUSDZJPY
# info        {'altname': 'USDJPY', 'wsname': 'USD/JPY', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     JPY
# quoteId                                                  ZJPY
# symbol                                                USD/JPY
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
# [17 rows x 179 columns]

# %%
# Fetch daily candlestick bar data from Top 5 Crypto
BTC_historical_prices = exchange.fetch_ohlcv("BTC/USD", "1d")
ETH_historical_prices = exchange.fetch_ohlcv("ETH/USD", "1d")
XRP_historical_prices = exchange.fetch_ohlcv("XRP/USD", "1d")
BCH_historical_prices = exchange.fetch_ohlcv("BCH/USD", "1d")
LTC_historical_prices = exchange.fetch_ohlcv("LTC/USD", "1d")
USDT_historical_prices = exchange.fetch_ohlcv("USDT/USD", "1d")
EOS_historical_prices = exchange.fetch_ohlcv("EOS/USD", "1d")
# BNB_historical_prices = exchange.fetch_ohlcv("BNB/USD", "1d")
# BSV_historical_prices = exchange.fetch_ohlcv("BSV/USD", "1d")
XLM_historical_prices = exchange.fetch_ohlcv("XLM/USD", "1d")

# Import the data as a Pandas DataFrame and set the columns
BTC_historical_prices_df = pd.DataFrame(
    BTC_historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

ETH_historical_prices_df = pd.DataFrame(
    ETH_historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

XRP_historical_prices_df = pd.DataFrame(
    XRP_historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

BCH_historical_prices_df = pd.DataFrame(
    BCH_historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

LTC_historical_prices_df = pd.DataFrame(
    LTC_historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

USDT_historical_prices_df = pd.DataFrame(
    USDT_historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

EOS_historical_prices_df = pd.DataFrame(
    EOS_historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

XLM_historical_prices_df = pd.DataFrame(
    XLM_historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"])

# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter and set date as index
BTC_historical_prices_df["date"] = pd.to_datetime(BTC_historical_prices_df["timestamp"], unit="ms")
BTC_historical_prices_df.set_index("date", inplace=True)

ETH_historical_prices_df["date"] = pd.to_datetime(ETH_historical_prices_df["timestamp"], unit="ms")
ETH_historical_prices_df.set_index("date", inplace=True)

XRP_historical_prices_df["date"] = pd.to_datetime(XRP_historical_prices_df["timestamp"], unit="ms")
XRP_historical_prices_df.set_index("date", inplace=True)

BCH_historical_prices_df["date"] = pd.to_datetime(BCH_historical_prices_df["timestamp"], unit="ms")
BCH_historical_prices_df.set_index("date", inplace=True)

LTC_historical_prices_df["date"] = pd.to_datetime(LTC_historical_prices_df["timestamp"], unit="ms")
LTC_historical_prices_df.set_index("date", inplace=True)

USDT_historical_prices_df["date"] = pd.to_datetime(USDT_historical_prices_df["timestamp"], unit="ms")
USDT_historical_prices_df.set_index("date", inplace=True)

EOS_historical_prices_df["date"] = pd.to_datetime(EOS_historical_prices_df["timestamp"], unit="ms")
EOS_historical_prices_df.set_index("date", inplace=True)

XLM_historical_prices_df["date"] = pd.to_datetime(XLM_historical_prices_df["timestamp"], unit="ms")
XLM_historical_prices_df.set_index("date", inplace=True)

# %%
# Drop all columns but Close pricing and Concat the Crypto dataframes
Crypto_historical_prices_df = pd.concat([
    BTC_historical_prices_df.drop(columns = ["timestamp", "open", "high", "low", "volume"], inplace = False)
    .rename(columns={"close": "BTC Closing"}),
    ETH_historical_prices_df.drop(columns = ["timestamp", "open", "high", "low", "volume"],inplace = False)
    .rename(columns={"close": "ETH Closing"}),
    XRP_historical_prices_df.drop(columns = ["timestamp", "open", "high", "low", "volume"],inplace = False)
    .rename(columns={"close": "XRP Closing"}),
    BCH_historical_prices_df.drop(columns = ["timestamp", "open", "high", "low", "volume"],inplace = False)
    .rename(columns={"close": "BCH Closing"}),
    LTC_historical_prices_df.drop(columns = ["timestamp", "open", "high", "low", "volume"],inplace = False)
    .rename(columns={"close": "LTC Closing"}),
    USDT_historical_prices_df.drop(columns = ["timestamp", "open", "high", "low", "volume"],inplace = False)
    .rename(columns={"close": "USDT Closing"}),
    EOS_historical_prices_df.drop(columns = ["timestamp", "open", "high", "low", "volume"],inplace = False)
    .rename(columns={"close": "EOS Closing"}),
    XLM_historical_prices_df.drop(columns = ["timestamp", "open", "high", "low", "volume"],inplace = False)
    .rename(columns={"close": "XLM Closing"})
], axis = 'columns', join = 'inner')

# %%
Crypto_historical_prices_df.head()
# Out:
#             BTC Closing  ETH Closing  XRP Closing  BCH Closing  LTC Closing  \
# date
# 2018-07-19       7472.3       468.45      0.47629        825.6        86.10
# 2018-07-20       7320.0       447.95      0.44360        762.5        81.63
# 2018-07-21       7396.7       460.88      0.45286        787.3        83.49
# 2018-07-22       7401.1       457.34      0.44979        784.8        82.33
# 2018-07-23       7720.0       449.38      0.44555        782.4        81.52
#
#             USDT Closing  EOS Closing  XLM Closing
# date
# 2018-07-19        0.9999       8.3881     0.305290
# 2018-07-20        0.9981       7.8300     0.269272
# 2018-07-21        0.9999       8.0149     0.292800
# 2018-07-22        0.9988       7.8363     0.283689
# 2018-07-23        0.9976       7.9349     0.286605

# %%
# returns of crypto
Crypto_returns_df = Crypto_historical_prices_df.pct_change()

# Drop Nulls
Crypto_returns_df.dropna(inplace = True)

# %%
Crypto_returns_df.head()
# Out:
#             BTC Closing  ETH Closing  XRP Closing  BCH Closing  LTC Closing  \
# date
# 2018-07-20    -0.020382    -0.043761    -0.068635    -0.076429    -0.051916
# 2018-07-21     0.010478     0.028865     0.020875     0.032525     0.022786
# 2018-07-22     0.000595    -0.007681    -0.006779    -0.003175    -0.013894
# 2018-07-23     0.043088    -0.017405    -0.009427    -0.003058    -0.009838
# 2018-07-24     0.088316     0.070653     0.027090     0.107745     0.094701
#
#             USDT Closing  EOS Closing  XLM Closing
# date
# 2018-07-20     -0.001800    -0.066535    -0.117980
# 2018-07-21      0.001803     0.023614     0.087376
# 2018-07-22     -0.001100    -0.022283    -0.031117
# 2018-07-23     -0.001201     0.012582     0.010279
# 2018-07-24      0.001002     0.083555     0.049877

# %%
# the function that we'll optimize is "neg_portfolio_sharpR"
def neg_portfolio_sharpR (weights):
    crypto_portfolio_df = Crypto_returns_df.dot(weights)
    # We need cumulative returns
    crypto_cum_returns_df = ( 1 + crypto_portfolio_df).cumprod()
    # Then we solve for annual_return
    crypto_returns_annual = (crypto_cum_returns_df)**(365/(b -a).days) - 1
    crypto_returns_annual = crypto_returns_annual[-1]

    crypto_returns_sd_ann = crypto_portfolio_df.std()*np.sqrt(252)
    # we'll use a minimization routine
    # so we define the Sharpe_ratio as negative
    return (-crypto_returns_annual/crypto_returns_sd_ann)

# %%
from scipy.optimize import minimize
import numpy as np

# %%
num_assets = 8
# The constraint is that the sum of weights needs to be equal to 1:
constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
bound = (0.0,1.0) # no negative weights (no short-selling)
bounds = tuple(bound for asset in range(num_assets))
# We use the Sequential Least SQuares Programming (SLSQP) Algorithm
result = minimize(neg_portfolio_sharpR, num_assets*[1./num_assets,],
                        method='SLSQP', bounds=bounds, constraints=constraints)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-5c5a443f8898> in <module>
#       6 # We use the Sequential Least SQuares Programming (SLSQP) Algorithm
#       7 result = minimize(neg_portfolio_sharpR, num_assets*[1./num_assets,],
# ----> 8                         method='SLSQP', bounds=bounds, constraints=constraints)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616     elif meth == 'slsqp':
#     617         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 618                                constraints, callback=callback, **options)
#     619     elif meth == 'trust-constr':
#     620         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     397
#     398             # Compute objective function
# --> 399             fx = func(x)
#     400             try:
#     401                 fx = float(np.asarray(fx))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# <ipython-input-61-9996d9ad8e9f> in neg_portfolio_sharpR(weights)
#       5     crypto_cum_returns_df = ( 1 + crypto_portfolio_df).cumprod()
#       6     # Then we solve for annual_return
# ----> 7     crypto_returns_annual = (crypto_cum_returns_df)**(365/(b -a).days) - 1
#       8     crypto_returns_annual = crypto_returns_annual[-1]
#       9
#
# NameError: name 'b' is not defined

# %%
# optimal Sharpe ratio is the negative of the minimum
optimal_Sharpe = -result.fun
optimal_Sharpe

# %%
opt_weights = pd.DataFrame(result.x)
opt_weights

# %%
# setting up weights in a dataframe
def opt_weights_df(results):
    opt_weights_df = pd.DataFrame(result.x).transpose()
    # renaming columns with tickers names
    opt_weights_df = pd.DataFrame (data = opt_weights_df.values, columns = returns_df.columns)
    return opt_weights_df

# %%
opt_weights_df(result)

# %%
# fixing the dataframe with weights in order to
# be able to plot a pie
opt_weights_transpose = opt_weights_df(result).T
opt_weights_transpose['weights'] = opt_weights_transpose[0] 
opt_weights_transpose.reset_index(inplace=True)
opt_weights_transpose
